# %% [markdown]
# # This document highlight how to collect CRIM meta data files from the master csv.

# %%
import requests
import pandas as pd

# %%
names = pd.read_csv('https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_File_List.csv')
#names[names['Status'].str.match('Y')]
names.head()
# Out:
#                                             Root_URL                 Name  \
# 0  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0001.mei
# 1  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0002.mei
# 2  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0003.mei
# 3  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0004.mei
# 4  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0005.mei
#
#    Complete URL Status
# 0           NaN      Y
# 1           NaN      Y
# 2           NaN      Y
# 3           NaN      Y
# 4           NaN      Y

# %%
names["Complete URL"] = names["Root_URL"] + names["Name"]

# %%
names.head()
# Out:
#                                             Root_URL                 Name  \
# 0  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0001.mei
# 1  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0002.mei
# 2  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0003.mei
# 3  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0004.mei
# 4  https://raw.githubusercontent.com/CRIM-Project...  CRIM_Model_0005.mei
#
#                                         Complete URL Status
# 0  https://raw.githubusercontent.com/CRIM-Project...      Y
# 1  https://raw.githubusercontent.com/CRIM-Project...      Y
# 2  https://raw.githubusercontent.com/CRIM-Project...      Y
# 3  https://raw.githubusercontent.com/CRIM-Project...      Y
# 4  https://raw.githubusercontent.com/CRIM-Project...      Y

# %%
filtered=names['Status']=='Y'
final = names[filtered]
final.head(50)
# Out:
#                                              Root_URL                  Name  \
# 0   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0001.mei
# 1   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0002.mei
# 2   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0003.mei
# 3   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0004.mei
# 4   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0005.mei
# 5   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0006.mei
# 6   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0007.mei
# 7   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0008.mei
# 8   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0009.mei
# 9   https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0010.mei
# 10  https://raw.githubusercontent.com/CRIM-Project...   CRIM_Model_0011.mei
# ...

# %%
# final.to_csv('names.csv')
